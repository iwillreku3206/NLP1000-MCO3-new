# %% [markdown]
# # Load Libraries

# %%
from nltk import edit_distance
from scipy.spatial.distance import pdist, squareform
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns
from matplotlib.colors import LogNorm, Normalize
from Levenshtein import distance

# %% [markdown]
# # Load Verses

# %%
txt_dir = "cleaned"

dir = os.listdir(txt_dir)

languages = {}

for filename in dir:
    match = re.match("([a-z]*(?:-a)?)(?:-(?:tl))?_cleaned\\.verses\\.csv", filename)
    if match is not None:
        language = (match[1])
        path = os.path.join(txt_dir, filename)
        print(path)
        languages[language] = pd.read_csv(path, quotechar='"')
# Out:
# cleaned\bantoanon_cleaned.verses.csv
# cleaned\bicol_cleaned.verses.csv
# cleaned\cebuano_cleaned.verses.csv
# cleaned\chavacano_cleaned.verses.csv
# cleaned\english_cleaned.verses.csv
# cleaned\filipino-tl_cleaned.verses.csv
# cleaned\ilokano_cleaned.verses.csv
# cleaned\ilonggo_cleaned.verses.csv
# cleaned\ivatan_cleaned.verses.csv
# cleaned\kinaray-a_cleaned.verses.csv
# cleaned\manobo_cleaned.verses.csv
# cleaned\masbatenyo_cleaned.verses.csv
# cleaned\pampanga_cleaned.verses.csv
# cleaned\pangasinan_cleaned.verses.csv
# cleaned\romblomanon_cleaned.verses.csv
# cleaned\sambal_cleaned.verses.csv
# cleaned\spanish_cleaned.verses.csv
# cleaned\tausug_cleaned.verses.csv
# cleaned\waray_cleaned.verses.csv
# cleaned\yakan_cleaned.verses.csv
# cleaned\yami_cleaned.verses.csv

# %% [markdown]
# # Remove Unneeded Books

# %%
books = languages['english']['Book_Code'].unique()
books
# Out:
# array(['GEN', 'EXO', 'LEV', 'NUM', 'DEU', 'JOS', 'JDG', 'RUT', '1SA',
#        '2SA', '1KI', '2KI', '1CH', '2CH', 'EZR', 'NEH', 'EST', 'JOB',
#        'PSA', 'PRO', 'ECC', 'SNG', 'ISA', 'JER', 'LAM', 'EZK', 'DAN',
#        'HOS', 'JOL', 'AMO', 'OBA', 'JON', 'MIC', 'NAM', 'HAB', 'ZEP',
#        'HAG', 'ZEC', 'MAL', 'MAT', 'MRK', 'LUK', 'JHN', 'ACT', 'ROM',
#        '1CO', '2CO', 'GAL', 'EPH', 'PHP', 'COL', '1TH', '2TH', '1TI',
#        '2TI', 'TIT', 'PHM', 'HEB', 'JAS', '1PE', '2PE', '1JN', '2JN',
#        '3JN', 'JUD', 'REV'], dtype=object)

# %%
languages_books_filtered = {}

for language in languages:
    languages_books_filtered[language] = languages[language][languages[language]['Book_Code'].isin(books)].dropna()

languages_books_filtered['english']
# Out:
#       Book_Code  Chapter  Verse  \
# 0           GEN        1      1
# 1           GEN        1      2
# 2           GEN        1      3
# 3           GEN        1      4
# 4           GEN        1      5
# ...         ...      ...    ...
# 31213       REV       22     17
# 31214       REV       22     18
# 31215       REV       22     19
# 31216       REV       22     20
# 31217       REV       22     21
#
#                                                     Text
# 0      In the beginning God created the heaven and th...
# 1      And the earth was without form, and void; and ...
# 2      And God said, Let there be light: and there wa...
# 3      And God saw the light, that it was good: and G...
# 4      And God called the light Day, and the darkness...
# ...                                                  ...
# 31213  And the Spirit and the bride say, Come. And le...
# 31214  For I testify unto every man that heareth the ...
# 31215  and if any man shall take away from the words ...
# 31216  He which testifieth these things saith, Surely...
# 31217  The grace of our Lord Jesus Christ be with you...
#
# [31218 rows x 4 columns]

# %% [markdown]
# # Create Parallel Corpora

# %%
languages_bcv_map = {} # BCV = Book, Chapter, Verse
for language in languages_books_filtered:
    languages_bcv_map[language] = {}

    for row in languages_books_filtered[language].itertuples():
        if row[1] not in languages_bcv_map[language]:
            languages_bcv_map[language][row[1]] = {}
        if row[2] not in languages_bcv_map[language][row[1]]:
            languages_bcv_map[language][row[1]][row[2]] = []
        languages_bcv_map[language][row[1]][row[2]].append((row[3], row[4]))

# %%
parallel_corpora = []
parallel_corpora_done = {}
max = 0

corpora_counter = 0
for language in languages_bcv_map:
    for language2 in languages_bcv_map:
        if language == language2:
            continue
        if (language2, language) in parallel_corpora_done:
            continue
        if (language, language2) not in parallel_corpora_done and (language2, language) not in parallel_corpora_done:
            parallel_corpora_done[(language, language2)] = True
        else:
            continue
        corpora_counter += 1
        print((language, language2, corpora_counter))
        for book in languages_bcv_map[language]:
            if book not in languages_bcv_map[language2]:
                continue
            for chapter in languages_bcv_map[language][book]:
                if chapter not in languages_bcv_map[language2][book]:
                    continue
                if re.match("([0-9]*)-?([0-9]*)?", str(languages_bcv_map[language][book][chapter][0][0]))[1] != '1':
                    continue
                if re.match("([0-9]*)-?([0-9]*)?", str(languages_bcv_map[language2][book][chapter][0][0]))[1] != '1':
                    continue
                min = 1
                left_index = 0
                right_index = 0
                left_max = 1
                right_max = 1
                left_curr = ""
                right_curr = ""
                left_update = True
                right_update = True
                while left_max != right_max or left_index <= len(languages_bcv_map[language][book][chapter]) - 1 or right_index <= len(languages_bcv_map[language2][book][chapter]) - 1:
                    if left_index > len(languages_bcv_map[language][book][chapter]) - 1 or right_index > len(languages_bcv_map[language2][book][chapter]) - 1:
                        break
                    left_verse = languages_bcv_map[language][book][chapter][left_index]
                    right_verse = languages_bcv_map[language2][book][chapter][right_index]
                    if '-' in str(left_verse[0]):
                        left_max = int(re.match('[0-9]*-([0-9]*)', str(left_verse[0]))[1])
                    else:
                        left_max = int(left_verse[0])
                    if left_update:
                        left_curr += left_verse[1]

                    if '-' in str(right_verse[0]):
                        right_max = int(re.match('[0-9]*-([0-9]*)', str(right_verse[0]))[1])
                    else:
                        right_max = int(right_verse[0])
                    if right_update:
                        right_curr += right_verse[1]

                    if left_max < right_max:
                        left_index += 1
                        left_update = True
                    elif left_max > right_max:
                        right_index += 1
                        right_update = True
                    else:
                        # we synced, push this
                        left_update = right_update = True
                        left_index += 1
                        right_index += 1
                        parallel_corpora.append((language, language2, book, chapter, str(min)+'-'+str(left_max) if min != left_max else str(min), left_curr, right_curr))
                        left_curr = ""
                        right_curr = ""
                        min = left_max + 1
# Out:
# ('bantoanon', 'bicol', 1)
# ('bantoanon', 'cebuano', 2)
# ('bantoanon', 'chavacano', 3)
# ('bantoanon', 'english', 4)
# ('bantoanon', 'filipino', 5)
# ('bantoanon', 'ilokano', 6)
# ('bantoanon', 'ilonggo', 7)
# ('bantoanon', 'ivatan', 8)
# ('bantoanon', 'kinaray-a', 9)
# ('bantoanon', 'manobo', 10)
# ('bantoanon', 'masbatenyo', 11)
# ('bantoanon', 'pampanga', 12)
# ('bantoanon', 'pangasinan', 13)
# ('bantoanon', 'romblomanon', 14)
# ('bantoanon', 'sambal', 15)
# ('bantoanon', 'spanish', 16)
# ('bantoanon', 'tausug', 17)
# ('bantoanon', 'waray', 18)
# ('bantoanon', 'yakan', 19)
# ('bantoanon', 'yami', 20)
# ('bicol', 'cebuano', 21)
# ('bicol', 'chavacano', 22)
# ('bicol', 'english', 23)
# ('bicol', 'filipino', 24)
# ('bicol', 'ilokano', 25)
# ('bicol', 'ilonggo', 26)
# ('bicol', 'ivatan', 27)
# ('bicol', 'kinaray-a', 28)
# ('bicol', 'manobo', 29)
# ('bicol', 'masbatenyo', 30)
# ('bicol', 'pampanga', 31)
# ('bicol', 'pangasinan', 32)
# ('bicol', 'romblomanon', 33)
# ('bicol', 'sambal', 34)
# ('bicol', 'spanish', 35)
# ('bicol', 'tausug', 36)
# ('bicol', 'waray', 37)
# ('bicol', 'yakan', 38)
# ('bicol', 'yami', 39)
# ('cebuano', 'chavacano', 40)
# ('cebuano', 'english', 41)
# ('cebuano', 'filipino', 42)
# ('cebuano', 'ilokano', 43)
# ('cebuano', 'ilonggo', 44)
# ('cebuano', 'ivatan', 45)
# ('cebuano', 'kinaray-a', 46)
# ('cebuano', 'manobo', 47)
# ('cebuano', 'masbatenyo', 48)
# ('cebuano', 'pampanga', 49)
# ('cebuano', 'pangasinan', 50)
# ('cebuano', 'romblomanon', 51)
# ('cebuano', 'sambal', 52)
# ('cebuano', 'spanish', 53)
# ('cebuano', 'tausug', 54)
# ('cebuano', 'waray', 55)
# ('cebuano', 'yakan', 56)
# ('cebuano', 'yami', 57)
# ('chavacano', 'english', 58)
# ('chavacano', 'filipino', 59)
# ('chavacano', 'ilokano', 60)
# ('chavacano', 'ilonggo', 61)
# ('chavacano', 'ivatan', 62)
# ('chavacano', 'kinaray-a', 63)
# ('chavacano', 'manobo', 64)
# ('chavacano', 'masbatenyo', 65)
# ('chavacano', 'pampanga', 66)
# ('chavacano', 'pangasinan', 67)
# ('chavacano', 'romblomanon', 68)
# ('chavacano', 'sambal', 69)
# ('chavacano', 'spanish', 70)
# ('chavacano', 'tausug', 71)
# ('chavacano', 'waray', 72)
# ('chavacano', 'yakan', 73)
# ('chavacano', 'yami', 74)
# ('english', 'filipino', 75)
# ('english', 'ilokano', 76)
# ('english', 'ilonggo', 77)
# ('english', 'ivatan', 78)
# ('english', 'kinaray-a', 79)
# ('english', 'manobo', 80)
# ('english', 'masbatenyo', 81)
# ('english', 'pampanga', 82)
# ('english', 'pangasinan', 83)
# ('english', 'romblomanon', 84)
# ('english', 'sambal', 85)
# ('english', 'spanish', 86)
# ('english', 'tausug', 87)
# ('english', 'waray', 88)
# ('english', 'yakan', 89)
# ('english', 'yami', 90)
# ('filipino', 'ilokano', 91)
# ('filipino', 'ilonggo', 92)
# ('filipino', 'ivatan', 93)
# ('filipino', 'kinaray-a', 94)
# ('filipino', 'manobo', 95)
# ('filipino', 'masbatenyo', 96)
# ('filipino', 'pampanga', 97)
# ('filipino', 'pangasinan', 98)
# ('filipino', 'romblomanon', 99)
# ('filipino', 'sambal', 100)
# ('filipino', 'spanish', 101)
# ('filipino', 'tausug', 102)
# ('filipino', 'waray', 103)
# ('filipino', 'yakan', 104)
# ('filipino', 'yami', 105)
# ('ilokano', 'ilonggo', 106)
# ('ilokano', 'ivatan', 107)
# ('ilokano', 'kinaray-a', 108)
# ('ilokano', 'manobo', 109)
# ('ilokano', 'masbatenyo', 110)
# ('ilokano', 'pampanga', 111)
# ('ilokano', 'pangasinan', 112)
# ('ilokano', 'romblomanon', 113)
# ('ilokano', 'sambal', 114)
# ('ilokano', 'spanish', 115)
# ('ilokano', 'tausug', 116)
# ('ilokano', 'waray', 117)
# ('ilokano', 'yakan', 118)
# ('ilokano', 'yami', 119)
# ('ilonggo', 'ivatan', 120)
# ('ilonggo', 'kinaray-a', 121)
# ('ilonggo', 'manobo', 122)
# ('ilonggo', 'masbatenyo', 123)
# ('ilonggo', 'pampanga', 124)
# ('ilonggo', 'pangasinan', 125)
# ('ilonggo', 'romblomanon', 126)
# ('ilonggo', 'sambal', 127)
# ('ilonggo', 'spanish', 128)
# ('ilonggo', 'tausug', 129)
# ('ilonggo', 'waray', 130)
# ('ilonggo', 'yakan', 131)
# ('ilonggo', 'yami', 132)
# ('ivatan', 'kinaray-a', 133)
# ('ivatan', 'manobo', 134)
# ('ivatan', 'masbatenyo', 135)
# ('ivatan', 'pampanga', 136)
# ('ivatan', 'pangasinan', 137)
# ('ivatan', 'romblomanon', 138)
# ('ivatan', 'sambal', 139)
# ('ivatan', 'spanish', 140)
# ('ivatan', 'tausug', 141)
# ('ivatan', 'waray', 142)
# ('ivatan', 'yakan', 143)
# ('ivatan', 'yami', 144)
# ('kinaray-a', 'manobo', 145)
# ('kinaray-a', 'masbatenyo', 146)
# ('kinaray-a', 'pampanga', 147)
# ('kinaray-a', 'pangasinan', 148)
# ('kinaray-a', 'romblomanon', 149)
# ('kinaray-a', 'sambal', 150)
# ('kinaray-a', 'spanish', 151)
# ('kinaray-a', 'tausug', 152)
# ('kinaray-a', 'waray', 153)
# ('kinaray-a', 'yakan', 154)
# ('kinaray-a', 'yami', 155)
# ('manobo', 'masbatenyo', 156)
# ('manobo', 'pampanga', 157)
# ('manobo', 'pangasinan', 158)
# ('manobo', 'romblomanon', 159)
# ('manobo', 'sambal', 160)
# ('manobo', 'spanish', 161)
# ('manobo', 'tausug', 162)
# ('manobo', 'waray', 163)
# ('manobo', 'yakan', 164)
# ('manobo', 'yami', 165)
# ('masbatenyo', 'pampanga', 166)
# ('masbatenyo', 'pangasinan', 167)
# ('masbatenyo', 'romblomanon', 168)
# ('masbatenyo', 'sambal', 169)
# ('masbatenyo', 'spanish', 170)
# ('masbatenyo', 'tausug', 171)
# ('masbatenyo', 'waray', 172)
# ('masbatenyo', 'yakan', 173)
# ('masbatenyo', 'yami', 174)
# ('pampanga', 'pangasinan', 175)
# ('pampanga', 'romblomanon', 176)
# ('pampanga', 'sambal', 177)
# ('pampanga', 'spanish', 178)
# ('pampanga', 'tausug', 179)
# ('pampanga', 'waray', 180)
# ('pampanga', 'yakan', 181)
# ('pampanga', 'yami', 182)
# ('pangasinan', 'romblomanon', 183)
# ('pangasinan', 'sambal', 184)
# ('pangasinan', 'spanish', 185)
# ('pangasinan', 'tausug', 186)
# ('pangasinan', 'waray', 187)
# ('pangasinan', 'yakan', 188)
# ('pangasinan', 'yami', 189)
# ('romblomanon', 'sambal', 190)
# ('romblomanon', 'spanish', 191)
# ('romblomanon', 'tausug', 192)
# ('romblomanon', 'waray', 193)
# ('romblomanon', 'yakan', 194)
# ('romblomanon', 'yami', 195)
# ('sambal', 'spanish', 196)
# ('sambal', 'tausug', 197)
# ('sambal', 'waray', 198)
# ('sambal', 'yakan', 199)
# ('sambal', 'yami', 200)
# ('spanish', 'tausug', 201)
# ('spanish', 'waray', 202)
# ('spanish', 'yakan', 203)
# ('spanish', 'yami', 204)
# ('tausug', 'waray', 205)
# ('tausug', 'yakan', 206)
# ('tausug', 'yami', 207)
# ('waray', 'yakan', 208)
# ('waray', 'yami', 209)
# ('yakan', 'yami', 210)

# %%
df = pd.DataFrame(data=parallel_corpora, columns=['language1', 'language2', 'book', 'chapter', 'verse', 'language1_text', 'language2_text'])

# %%
df
# Out:
#          language1 language2 book  chapter verse  \
# 0        bantoanon     bicol  GEN        1     1
# 1        bantoanon     bicol  GEN        1     2
# 2        bantoanon     bicol  GEN        1     3
# 3        bantoanon     bicol  GEN        1     4
# 4        bantoanon     bicol  GEN        1     5
# ...            ...       ...  ...      ...   ...
# 2636012      yakan      yami  REV       22    17
# 2636013      yakan      yami  REV       22    18
# 2636014      yakan      yami  REV       22    19
# 2636015      yakan      yami  REV       22    20
# 2636016      yakan      yami  REV       22    21
#
#                                             language1_text  \
# 0        Sa kauna-unahan, gingtuga it Dios kag langit a...
# 1        It kato, kag kalibutan ay waya it korte ag way...
# 2        Ag nagsiling kag Dios, "Magkainggwa't hadag!" ...
# 3        Nakita it Dios nak maado kag hadag, ag Ida ing...
# 4        Gingtawag it Dios kag hadag nak "adlaw" ag kag...
# ...                                                    ...
# 2636012  Nambag Niyawa Tuhanin duk pangantin dendehin, ...
# 2636013  Aku inin si Yahiya. Sessa'ante ka'am, sasuku k...
# 2636014  Bang niya' ngānan sinduwe me' pa'alan dem libr...
# 2636015  Inin ne bissāmanaksi' si kēmon pinakita'u dem ...
# 2636016  Karayaw ka'am kēmon ipat si Isa, Panuhutanten bi.
#
#                                             language2_text
# 0        Sa kapinonan, kan lalangon nin Dios an kalangi...
# 1        an kinaban mayo nin ano man na porma saka laog...
# 2        Nagboot an Dios, "Magkaigwa nin liwanag," asin...
# 3        Nahiling nin Dios na marahay an liwanag. Isinu...
# 4        dangan inapod niyang "Aldaw" an liwanag, asin ...
# ...                                                    ...
# 2636012  Maniring o Seyzi a kano Macivahavahay a mavake...
# 2636013  Yaken rana am si Yowani ko. Ko pa pakoyokoin j...
# 2636014  No amyan so tao a komteb do ciring a yadomket ...
# 2636015  Si Yeso a yamacyanoyong do aro a ciring eya am...
# 2636016  Inaoy si itoro na jinyo o pangangarilawan na n...
#
# [2636017 rows x 7 columns]

# %%
df.loc[df['language1'] == 'english'].head(5)
len(df)

df.to_csv('parallel_corpora.csv')
